# %% [markdown]
# # Variable (Değişkenler)

# %%
x = 5  # x değişkeni oluşturuyoruz ve bu değişkene 5 değerini atıyoruz.
y = 4  # artık x veya y dediğimizde x'in 5 olduğu, y'nin ise 4 olduğu biliniyor.
x*y    # ve sonuç 20 olacaktır
# Out:
# 20

# %%
x = 6  # x2 in değerini değiştirmek için tekrardan hücre içine x=6 yazarak x'in yeni değeri 6 olmuş olur.
x*y
# Out:
# 24

# %% [markdown]
# # Sayılar

# %%
type(x) # x'in veri tipini sorgulamak için
# Out:
# int

# %%
a =3
b =2
c = a/b

# %%
type(c)
# Out:
# float

# %% [markdown]
# # Matematiksel İşlemler

# %%
b = 5
y = 3

# %%
b*b*b*b
# Out:
# 625

# %%
b**4
# Out:
# 625

# %%
#remainder - kalanını bulmak
10 % 2
# Out:
# 0

# %%
5 % 2
# Out:
# 1

# %%
kullaniciYasi = input("Yaşınızı Giriniz: ") # buradaki değişkenin tipi (str) metindir.
# Out:
# Yaşınızı Giriniz: 21

# %%
type(kullaniciYasi)
# Out:
# str

# %%
kullaniciYasi * 5  # str tipinde olduğı için 5 kere yan yana yazdı
# Out:
# '2121212121'

# %% [markdown]
# # String

# %%
x = "Merhaba Dünya"

# %%
type(x)
# Out:
# str

# %%
y = 'hello world'

# %%
type(y)
# Out:
# str

# %%
y.capitalize()  # strinler ile kullanabileceğimiz fonksiyonlardan biri.. 
                # y değişkenindeki kelimenin baş harfini büyük harfe dönüştürdük.
# Out:
# 'Hello world'

# %%
kullaniciYasi = input("Yasinizi Giriniz:")
# Out:
# Yasinizi Giriniz:21

# %%
type(kullaniciYasi)                 # girilen input değerinin tipi str..
# Out:
# str

# %%
kullaniciYasi = int(kullaniciYasi)  #str tipini int tipine çeviriyoruz.

# %%
type(kullaniciYasi)
# Out:
# int

# %%
kullaniciYasi * 5
# Out:
# 105

# %%
b = "Busray"

# %%
len(b)      # değişken içindeki stringin kaç karakterden oluştuğu bilgisi verir.
# Out:
# 6

# %%
print("merhaba \nBusray")    # \n satır başına geçmemizi sağlar.
# Out:
# merhaba
# Busray

# %% [markdown]
# # Index

# %%
isim ="Busra yıldırım"

# %%
isim[0]
# Out:
# 'B'

# %%
isim[5]
# Out:
# ' '

# %%
isim[-1]
# Out:
# 'm'

# %% [markdown]
# # Slicing (dilimleme)

# %%
isim[5:]     # 5.(5. indeks dahil) indeksden itibaren..
# Out:
# ' yıldırım'

# %%
isim[-2:]
# Out:
# 'ım'

# %%
#step size
isim[1:10:3]   #1. indeks den başlayıp 3 er adımlarla 10. indeks dahil yazdır.
# Out:
# 'uaı'

# %%
isim[::-1]     #tam tersini yazmayı deneyelim :)
# Out:
# 'mırıdlıy arsuB'

# %% [markdown]
# # string metodları

# %%
isim.upper()      #tüm string karkterlerini büyük harfe çevirir
# Out:
# 'BUSRA YILDIRIM'

# %%
a = isim.split()  # değişken içindeki kelimeleri dizi içerisinde tutar.
a
# Out:
# ['Busra', 'yıldırım']

# %%
a[0]
# Out:
# 'Busra'
